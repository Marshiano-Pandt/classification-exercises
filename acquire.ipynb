# %% [markdown]
# ## Acquire

# %% [markdown]
# What is it?
#
# getting the data into a python dataframe
#
# Pipeline: Plan - Acquire - Prepare - Explore - Model - Deliver
#
# Why do we care?
#
# sets us up to use the pandas library for analyzing our data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from pydataset import data

import env
import os

from sklearn.datasets import load_iris

# %% [markdown]
# 1. Use pydata to import the iris data. Create a pandas dataframe, df_iris, from this data.
#
# print the first 3 rows
#
# print the number of rows and columns (shape)
#
# print the column names
#
# print the data type of each column
#
# print the summary statistics for each of the numeric variables

# %%
iris = load_iris()

iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# print the first 3 rows

# %%
iris_df.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2

# %% [markdown]
# print the number of rows and columns (shape)

# %%
iris_df.shape
# Out:
# (150, 4)

# %% [markdown]
# print the column names

# %%
iris_df.columns.values.tolist()
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# print the data type of each column

# %%
iris_df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# dtype: object

# %% [markdown]
# print the summary statistics for each of the numeric variables

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# Read the data from this google sheet into a dataframe, df_google.
#
# print the first 3 rows
# print the number of rows and columns
# print the column names
# print the data type of each column
# print the summary statistics for each of the numeric variables
# print the unique values for each of your categorical variables

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'

# %%
new_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
new_url
# Out:
# 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/export?format=csv&gid=341089357'

# %%
plane_df = pd.read_csv(new_url)

# %% [markdown]
# print the first 3 rows

# %%
plane_df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
plane_df.shape
# Out:
# (891, 12)

# %%
plane_df.columns.values.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
plane_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
plane_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
plane_df[[ 'Survived', 'Pclass', 'Name', 'Sex', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']].apply(pd.unique)
# Out:
# Survived                                               [0, 1]
# Pclass                                              [3, 1, 2]
# Name        [Braund, Mr. Owen Harris, Cumings, Mrs. John B...
# Sex                                            [male, female]
# SibSp                                   [1, 0, 3, 4, 2, 5, 8]
# Parch                                   [0, 1, 2, 5, 3, 4, 6]
# Ticket      [A/5 21171, PC 17599, STON/O2. 3101282, 113803...
# Fare        [7.25, 71.2833, 7.925, 53.1, 8.05, 8.4583, 51....
# Cabin       [nan, C85, C123, E46, G6, C103, D56, A6, C23 C...
# Embarked                                       [S, C, Q, nan]
# dtype: object

# %%
plane_df.Name.value_counts()
# Out:
# Name
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: count, Length: 891, dtype: int64

# %%
plane_df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
cat_col = plane_df.columns [plane_df.nunique() < 10]
cat_col
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked'], dtype='object')

# %%
for col in cat_col:
    print(col)
    print(plane_df[col].value_counts())
    print()
# Out:
# Survived
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
#
# Pclass
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
#
# Sex
# Sex
# male      577
# female    314
# Name: count, dtype: int64
#
# SibSp
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64
#
# Parch
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64
#
# Embarked
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
plane_df.Cabin.value_counts()
# Out:
# Cabin
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: count, Length: 147, dtype: int64

# %%
plane_df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plane_df.Survived.astype(object)
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: object

# %%
plane_df.Survived = plane_df.Survived.astype(object)

# %%
plane_df.select_dtypes(include='object')
# Out:
#     Survived                                               Name     Sex  \
# 0          0                            Braund, Mr. Owen Harris    male
# 1          1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2          1                             Heikkinen, Miss. Laina  female
# 3          1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4          0                           Allen, Mr. William Henry    male
# ..       ...                                                ...     ...
# 886        0                              Montvila, Rev. Juozas    male
# 887        1                       Graham, Miss. Margaret Edith  female
# 888        0           Johnston, Miss. Catherine Helen "Carrie"  female
# 889        1                              Behr, Mr. Karl Howell    male
# 890        0                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# ...

# %% [markdown]
# Download the google sheet from Exercise 6 into an .xslx (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.
#
# assign the first 100 rows to a new dataframe, df_excel_sample
# print the number of rows of your original dataframe
# print the first 5 column names
# print the column names that have a data type of object
# compute the range for each of the numeric variables.

# %% [markdown]
# ## Download the google sheet from Exercise 6 into an .xlsx (File → Download → Microsoft Excel). Read the downloaded file into a dataframe named df_excel.

# %%
df_excel = pd.read_excel('~/Downloads/train.xlsx')

# %% [markdown]
# assign the first 100 rows to a new dataframe, df_excel_sample

# %%
df_excel_sample = df_excel.head(100).copy()

# %%
# print the number of rows of your original dataframe

df_excel.shape
# Out:
# (891, 12)

# %%
# print the first 5 column names

df_excel_sample.columns[:5]
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %%
# print the column names that have a data type of object

df_excel_sample.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_excel_sample.select_dtypes(include='object').columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# compute the range for each of the numeric variables.

num_col = df_excel_sample.select_dtypes(include='number').columns
num_col
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
df_excel_sample[col].max()
# Out:
# 'Woolner, Mr. Hugh'

# %%
df_excel_sample[col].min()
# Out:
# 'Ahlin, Mrs. Johan (Johanna Persdotter Larsson)'

# %%
for col in num_col:
    print(col),
    # print(df_excel_sample[col])
    print(f'the range of {col} is {df_excel_sample[col].max() - df_excel_sample[col].min()}')
    # print()
# Out:
# PassengerId
# the range of PassengerId is 99
# Survived
# the range of Survived is 1
# Pclass
# the range of Pclass is 2
# Age
# the range of Age is 70.17
# SibSp
# the range of SibSp is 5
# Parch
# the range of Parch is 5
# Fare
# the range of Fare is 255.775

# %% [markdown]
# ## Make a new python module, acquire.py to hold the following data acquisition functions:
#
# ## Make a function named get_titanic_data that returns the Titanic data from the codeup data science database as a pandas data frame. Obtain your data from the Codeup Data Science Database.

# %%
def get_titanic_data():
    url = env.get_db_url(db='titanic_db')
    query = 'select * from passengers'
    
    df = pd.read_sql(query, url)
    return df

# %%
get_titanic_data().head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  deck  embark_town  alone
# 0        S  Third  None  Southampton      0
# 1        C  First     C    Cherbourg      0
# 2        S  Third  None  Southampton      1
# 3        S  First     C  Southampton      0
# 4        S  Third  None  Southampton      1

# %% [markdown]
# ## Make a function named get_iris_data that returns the data from the iris_db on the codeup data science database as a pandas data frame. The returned data frame should include the actual name of the species in addition to the species_ids. Obtain your data from the Codeup Data Science Database.

# %%
def get_iris_data():
    url = env.get_db_url('iris_db')
    query = '''
    select *
    from measurements 
        join species
            using(species_id)
    '''
    
    df = pd.read_sql(query, url)
    return df

# %%
get_iris_data().head()
# Out:
#    species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0           1               1           5.1          3.5           1.4
# 1           1               2           4.9          3.0           1.4
# 2           1               3           4.7          3.2           1.3
# 3           1               4           4.6          3.1           1.5
# 4           1               5           5.0          3.6           1.4
#
#    petal_width species_name
# 0          0.2       setosa
# 1          0.2       setosa
# 2          0.2       setosa
# 3          0.2       setosa
# 4          0.2       setosa

# %% [markdown]
# ## Make a function named get_telco_data that returns the data from the telco_churn database in SQL. In your SQL, be sure to join contract_types, internet_service_types, payment_types tables with the customers table, so that the resulting dataframe contains all the contract, payment, and internet service options. Obtain your data from the Codeup Data Science Database.

# %%
def get_telco_data():
    url = env.get_db_url('telco_churn')
    query = '''
    select *
    from customers
        left join contract_types
            using(contract_type_id)
        left join internet_service_types
            using(internet_service_type_id)
        left join payment_types
            using(payment_type_id)
    '''
    
    df = pd.read_sql(query, url)
    return df

# %%
get_telco_data().head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %% [markdown]
# ## Once you've got your get_titanic_data, get_iris_data, and get_telco_data functions written, now it's time to add caching to them. To do this, edit the beginning of the function to check for the local filename of telco.csv, titanic.csv, or iris.csv. If they exist, use the .csv file. If the file doesn't exist, then produce the SQL and pandas necessary to create a dataframe, then write the dataframe to a .csv file with the appropriate name.

# %%
def check_file_exists(filename, query, url):
    if os.path.exists(filename):
        print('this file exists, reading csv')
        df = pd.read_csv(filename)
    else:
        print('this file doesnt exist, read from sql, and export to csv')
        df = pd.read_sql(query, url)
        df.to_csv(filename)
        
    return df

# %%
def get_titanic_data():
    url = env.get_db_url('titanic_db')
    query = 'select * from passengers'
    
    filename = 'titanic.csv'
    
    # call the check_file_exists function 
    df = check_file_exists(filename, query, url)
    return df

# %%
get_titanic_data()
# Out:
# this file exists, reading csv
#      Unnamed: 0  passenger_id  survived  pclass     sex   age  sibsp  parch  \
# 0             0             0         0       3    male  22.0      1      0
# 1             1             1         1       1  female  38.0      1      0
# 2             2             2         1       3  female  26.0      0      0
# 3             3             3         1       1  female  35.0      1      0
# 4             4             4         0       3    male  35.0      0      0
# ..          ...           ...       ...     ...     ...   ...    ...    ...
# 886         886           886         0       2    male  27.0      0      0
# 887         887           887         1       1  female  19.0      0      0
# 888         888           888         0       3  female   NaN      1      2
# 889         889           889         1       1    male  26.0      0      0
# 890         890           890         0       3    male  32.0      0      0
#
# ...

# %%
def get_iris_data():
    url = env.get_db_url('iris_db')
    query = ''' 
    select *
    from measurements
        join species
            using(species_id)
    '''
    
    filename = 'iris.csv'
    
    # call the check_file_exists function
    df = check_file_exists(filename, query, url)
    return df

# %%
get_iris_data()
# Out:
# this file doesnt exist, read from sql, and export to csv
#      species_id  measurement_id  sepal_length  sepal_width  petal_length  \
# 0             1               1           5.1          3.5           1.4
# 1             1               2           4.9          3.0           1.4
# 2             1               3           4.7          3.2           1.3
# 3             1               4           4.6          3.1           1.5
# 4             1               5           5.0          3.6           1.4
# 5             1               6           5.4          3.9           1.7
# 6             1               7           4.6          3.4           1.4
# 7             1               8           5.0          3.4           1.5
# 8             1               9           4.4          2.9           1.4
# 9             1              10           4.9          3.1           1.5
# 10            1              11           5.4          3.7           1.5
# ...

# %%
def get_telco_data():
    url = env.get_db_url('telco_churn')
    query = '''
    select * from customers
        left join contract_types
            using(contract_type_id)
        left join internet_service_types
            using(internet_service_type_id)
        left join payment_types
            using(payment_type_id)
    '''
    
    filename = 'telcho_churn.csv'
    
    # call the check_file_exists function
    df = check_file_exists(filename, query, url)
    return df

# %%
get_telco_data()
# Out:
# this file doesnt exist, read from sql, and export to csv
#       payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                   2                         1                 2  0002-ORFBO
# 1                   2                         1                 1  0003-MKNFE
# 2                   1                         2                 1  0004-TLHLJ
# 3                   1                         2                 1  0011-IGKFF
# 4                   2                         2                 1  0013-EXCHZ
# ...               ...                       ...               ...         ...
# 7038                2                         1                 2  9987-LUTYD
# 7039                1                         2                 1  9992-RRAMN
# 7040                2                         1                 1  9992-UJOEL
# 7041                2                         1                 3  9993-LHIEB
# ...
